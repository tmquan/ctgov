# %%
# ! pip install scikit-learn 
# ! pip install pdftotree

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import pdftotree

pdf_path = "NCT00000000_Genesys.pdf"
# Convert the PDF to a tree structure
tree = pdftotree.parse(pdf_path)

print(tree)
# Out:
# <?xml version="1.0" ?>
# <html>
# 	<head>
# 		<meta name="ocr-system" content="Converted from PDF by pdftotree 0.5.0"/>
# 		<meta name="ocr-capabilities" content="ocr_page ocr_table ocrx_block ocrx_word"/>
# 		<meta name="ocr-number-of-pages" content="4"/>
# 	</head>
# 	<body>
# 		<div class="ocr_page" id="page_1" title="bbox 0 0 612 792; ppageno 0">
# 			<div class="ocrx_block" pdftotree="header" title="bbox 67 91 89 104">
# 				<span class="ocrx_line" title="bbox 67 91 89 104">
# 					<span class="ocrx_word" title="bbox 67 91 85 104">1.0</span>
# 				</span>
# 			</div>
# 			<div class="ocrx_block" pdftotree="header" title="bbox 99 91 193 104">
# 				<span class="ocrx_line" title="bbox 99 91 193 104">
# 					<span class="ocrx_word" title="bbox 99 91 190 104">INTRODUCTION</span>
# 				</span>
# 			</div>
# 			<div class="ocrx_block" pdftotree="section_header" title="bbox 67 125 203 138">
# 				<span class="ocrx_line" title="bbox 67 125 203 138">
# ...

# %%
import plotly.express as px
import pandas as pd

# %%
# data = {'nct_id': ['NCT001', 'NCT002', 'NCT003', 'NCT004', 'NCT005'],
#         'brief_title': ['Trial A', 'Trial B', 'Trial C', 'Trial D', 'Trial E'],
#         'state': ['CA', 'NY', 'TX', 'FL', 'IL'],
#         'country': ['USA', 'USA', 'USA', 'USA', 'USA']}
# df = pd.DataFrame(data)

df = pd.read_csv("ctgov_20230417.csv")
df
# Out:
#             nct_id                                        brief_title  \
# 0      NCT00000143  Studies of Ocular Complications of AIDS (SOCA)...
# 1      NCT00000378  Antidepressant Treatment of Melancholia in Lat...
# 2      NCT00000620  Action to Control Cardiovascular Risk in Diabe...
# 3      NCT00001151         Studies With 1,25-Dihydroxycholecalciferol
# 4      NCT00001213  Cysteamine Eye Drops to Treat Corneal Crystals...
# ...            ...                                                ...
# 34978  NCT05490771  Testing Copanlisib as a Potential Targeted Tre...
# 34979  NCT05502081  Clinical Study to Compare Efficacy and Safety ...
# 34980  NCT05594173          Chewing and Oral Processing of Solid Food
# 34981  NCT05607147  Rutgers Pilot for Dental Health Care Worker SA...
# 34982  NCT05736861  ACTIV-6: COVID-19 Study of Repurposed Medicati...
#
#                                           official_title  \
# 0      Studies of Ocular Complications of AIDS (SOCA)...
# ...

# %%
# state_codes = {
#     "Alabama": "AL",
#     "Alaska": "AK",
#     "Arizona": "AZ",
#     "Arkansas": "AR",
#     "California": "CA",
#     "Colorado": "CO",
#     "Connecticut": "CT",
#     "Delaware": "DE",
#     "Florida": "FL",
#     "Georgia": "GA",
#     "Hawaii": "HI",
#     "Idaho": "ID",
#     "Illinois": "IL",
#     "Indiana": "IN",
#     "Iowa": "IA",
#     "Kansas": "KS",
#     "Kentucky": "KY",
#     "Louisiana": "LA",
#     "Maine": "ME",
#     "Maryland": "MD",
#     "Massachusetts": "MA",
#     "Michigan": "MI",
#     "Minnesota": "MN",
#     "Mississippi": "MS",
#     "Missouri": "MO",
#     "Montana": "MT",
#     "Nebraska": "NE",
#     "Nevada": "NV",
#     "New Hampshire": "NH",
#     "New Jersey": "NJ",
#     "New Mexico": "NM",
#     "New York": "NY",
#     "North Carolina": "NC",
#     "North Dakota": "ND",
#     "Ohio": "OH",
#     "Oklahoma": "OK",
#     "Oregon": "OR",
#     "Pennsylvania": "PA",
#     "Rhode Island": "RI",
#     "South Carolina": "SC",
#     "South Dakota": "SD",
#     "Tennessee": "TN",
#     "Texas": "TX",
#     "Utah": "UT",
#     "Vermont": "VT",
#     "Virginia": "VA",
#     "Washington": "WA",
#     "West Virginia": "WV",
#     "Wisconsin": "WI",
#     "Wyoming": "WY",
#     "District of Columbia": "DC",
#     "American Samoa": "AS",
#     "Guam": "GU",
#     "Northern Mariana Islands": "MP",
#     "Puerto Rico": "PR",
#     "United States Minor Outlying Islands": "UM",
#     "U.S. Virgin Islands": "VI",
# }

# %%
# # Map full name states to state codes using the pandas Series map() method
# df['state'] = df['state'].map(state_codes)
# # Plot the clinical trial locations using px.scatter_geo()
# fig = px.scatter_geo(df, 
#                      locations="state", 
#                      locationmode='USA-states', 
#                      color="state",
#                      hover_name="brief_title", 
#                      scope="usa")

# # Show the plot
# fig.show()

# %%
# # Define a dictionary that maps state codes to colors
# color_map = {'AL': '#1f77b4', 'AK': '#ff7f0e', 'AZ': '#2ca02c', 'AR': '#d62728', 'CA': '#9467bd',
#              'CO': '#8c564b', 'CT': '#e377c2', 'DE': '#7f7f7f', 'FL': '#bcbd22', 'GA': '#17becf',
#              'HI': '#ff33cc', 'ID': '#999999', 'IL': '#3399ff', 'IN': '#66ff66', 'IA': '#9966ff',
#              'KS': '#ff9933', 'KY': '#cc99ff', 'LA': '#ff99cc', 'ME': '#b2b2b2', 'MD': '#b300b3',
#              'MA': '#00cc99', 'MI': '#6666ff', 'MN': '#ff6666', 'MS': '#ffff66', 'MO': '#ff66cc',
#              'MT': '#9933ff', 'NE': '#00ccff', 'NV': '#ff6666', 'NH': '#99cc99', 'NJ': '#ff6699',
#              'NM': '#ffcc00', 'NY': '#ff9966', 'NC': '#66ff99', 'ND': '#666699', 'OH': '#cc66ff',
#              'OK': '#339933', 'OR': '#ff6666', 'PA': '#993366', 'RI': '#cc9966', 'SC': '#9999ff',
#              'SD': '#99ccff', 'TN': '#ff9966', 'TX': '#66ffcc', 'UT': '#66ccff', 'VT': '#ff99cc',
#              'VA': '#ccffff', 'WA': '#ffccff', 'WV': '#99ff66', 'WI': '#9933cc', 'WY': '#cc99ff'}

# # Use the color_map dictionary to set the color_discrete_map parameter in px.scatter_geo()
# fig = px.scatter_geo(df,
#                      locations="state",
#                      locationmode='USA-states',
#                      color="state",
#                      color_discrete_map=color_map,
#                      hover_name="brief_title",
#                      scope="usa")

# # Create a custom legend by modifying the layout properties
# fig.update_layout(
#     legend=dict(
#         orientation="h",
#         yanchor="bottom",
#         y=-0.2,
#         xanchor="left",
#         x=0,
#         title="State Codes",
#         title_font=dict(size=14),
#         font=dict(size=12),
#         bordercolor="black",
#         borderwidth=1,
#         bgcolor="white",
#         traceorder="normal",
#         itemwidth=50,
#         itemsizing="constant",
#         itemclick="toggleothers"
#     )
# )

# # Show the plot
# fig.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
